# %%
import pandas as pd
import numpy as np
import requests
import matplotlib as mpt
from datetime import datetime

# %%
from ggplot import *

# %%
wd_dt = pd.read_csv("201402_weather_data.csv")
trip_dt = pd.read_csv("201402_trip_data.csv")

# %%
trip_dt.head()
# Out:
#    Trip ID  Duration       Start Date             Start Station  \
# 0     4576        63  8/29/2013 14:13  South Van Ness at Market
# 1     4607        70  8/29/2013 14:42        San Jose City Hall
# 2     4130        71  8/29/2013 10:16   Mountain View City Hall
# 3     4251        77  8/29/2013 11:29        San Jose City Hall
# 4     4299        83  8/29/2013 12:02  South Van Ness at Market
#
#    Start Terminal         End Date               End Station  End Terminal  \
# 0              66  8/29/2013 14:14  South Van Ness at Market            66
# 1              10  8/29/2013 14:43        San Jose City Hall            10
# 2              27  8/29/2013 10:17   Mountain View City Hall            27
# 3              10  8/29/2013 11:30        San Jose City Hall            10
# 4              66  8/29/2013 12:04            Market at 10th            67
#
#    Bike # Subscription Type Zip Code
# 0     520        Subscriber    94127
# 1     661        Subscriber    95138
# ...

# %%
wd_dt.head()
# Out:
#         Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  8/29/2013                 74                  68                61
# 1  8/30/2013                 78                  69                60
# 2  8/31/2013                 71                  64                57
# 3   9/1/2013                 74                  66                58
# 4   9/2/2013                 75                  69                62
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               61               58              56            93
# 1               61               58              56            90
# 2               57               56              54            93
# 3               60               56              53            87
# 4               61               60              58            93
#
#    Mean_Humidity   Min_Humidity   ...    Mean_Visibility_Miles   \
# 0              75             57  ...                        10
# ...

# %%
datelst = pd.to_datetime(trip_dt['Start Date'])

# %%
d = (datelst[0])

# %%
datetime.strptime(trip_dt['Start Date'], '%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-e11387f1957d> in <module>()
# ----> 1 datetime.strptime(trip_dt['Start Date'], '%d/%m/%Y')
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
def dateConvert(date):
    try: 
        return(datetime.strptime(date, '%m/%d/%Y')) 
    except: 
        return(datetime.strptime(date,'%d/%m/%Y'))

# %%
trip_dt['Start Date'].apply(lambda x: dateConvert(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-87d5d0329d30> in dateConvert(date)
#       2     try:
# ----> 3         return(datetime.strptime(date, '%m/%d/%Y'))
#       4     except:
#
# c:\users\manje_000\appdata\local\programs\python\python36-32\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#
# c:\users\manje_000\appdata\local\programs\python\python36-32\lib\_strptime.py in _strptime(data_string, format)
#     364         raise ValueError("unconverted data remains: %s" %
# --> 365                           data_string[found.end():])
#     366
#
# ValueError: unconverted data remains:  14:13
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
datelst[0].strptime()
